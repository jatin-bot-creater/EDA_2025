# %%
import numpy as np 
import pandas as pd
Data={'Names':['Ramesh','Suresh','Sathish',np.nan],
     'Age':[np.nan,22,25,27],
     'City':['Pune','Mumbai',np.nan,'Delhi']}
df=pd.DataFrame(Data)
df
# Out:
#      Names   Age    City
# 0   Ramesh   NaN    Pune
# 1   Suresh  22.0  Mumbai
# 2  Sathish  25.0     NaN
# 3      NaN  27.0   Delhi

# %%
import numpy as np 
import pandas as pd
Data={'Names':['Ramesh','Suresh','Sathish',None],
     'Age':[None,22,25,27],
     'City':['Pune','Mumbai',None,'Delhi']}
df1=pd.DataFrame(Data)
df1
# Out:
#      Names   Age    City
# 0   Ramesh   NaN    Pune
# 1   Suresh  22.0  Mumbai
# 2  Sathish  25.0    None
# 3     None  27.0   Delhi

# %%
import numpy as np 
import pandas as pd
Data={'Names':['Ramesh','Suresh','Sathish',Null],
     'Age':[Null,22,25,27],
     'City':['Pune','Mumbai',Null,'Delhi']}
df2=pd.DataFrame(Data)
df2
# only np.nan and None consider as a none values
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[4], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 Data={'Names':['Ramesh','Suresh','Sathish',Null],
#       4      'Age':[Null,22,25,27],
#       5      'City':['Pune','Mumbai',Null,'Delhi']}
#       6 df1=pd.DataFrame(Data)
#       7 df1
#
# NameError: name 'Null' is not defined

# %%
df.to_csv('Missing_Values.csv',index=False)

# %%
df1.to_csv('Missing_Values1.csv',index=False)

# %%
df.dtypes
# Out:
# Names     object
# Age      float64
# City      object
# dtype: object

# %%
df1.dtypes
# Out:
# Names     object
# Age      float64
# City      object
# dtype: object

# %%
df.isnull()
# Out:
#    Names    Age   City
# 0  False   True  False
# 1  False  False  False
# 2  False  False   True
# 3   True  False  False

# %%
df.isnull().sum()
# Out:
# Names    1
# Age      1
# City     1
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# Names    1
# Age      1
# City     1
# dtype: int64

# %% [markdown]
# ## fillna

# %%
#df.fillna(30)

# %%
#df['Age'].fillna(30,inplace=True)
df
# Out:
#      Names   Age    City
# 0   Ramesh  30.0    Pune
# 1   Suresh  22.0  Mumbai
# 2  Sathish  25.0    None
# 3     None  27.0   Delhi

# %% [markdown]
# - the above one is we are filling randomly
# - all the columns are filled with random numbers
# - It is not good approch because in a data we have different datatypes

# %%
df.fillna('Hyd')
# Out:
#      Names   Age    City
# 0   Ramesh  30.0    Pune
# 1   Suresh  22.0  Mumbai
# 2  Sathish  25.0     Hyd
# 3      Hyd  27.0   Delhi

# %% [markdown]
# **What is the diffrent btw np.nan and none**

# %%
np.nan+5
# Out:
# nan

# %%
None+5
# Out:
# ----------------------------------------------------------------
# TypeError                      Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 None+5
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
arr1=np.array([1,2,np.nan,3])
arr2=np.array([1,2,None,3])

# %%
arr1
# Out:
# array([ 1.,  2., nan,  3.])

# %%
arr2
# Out:
# array([1, 2, None, 3], dtype=object)

# %%
np.nansum(arr1),np.sum(arr1)
# Out:
# (np.float64(6.0), np.float64(nan))

# %%
np.sum(arr2)
# None is very dangeous for the
# Out:
# ----------------------------------------------------------------
# TypeError                      Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 np.sum(arr2)
#
# File J:\Anconda\Lib\site-packages\numpy\_core\fromnumeric.py:2485, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2482         return out
#    2483     return res
# -> 2485 return _wrapreduction(
#    2486     a, np.add, 'sum', axis, dtype, out,
#    2487     keepdims=keepdims, initial=initial, where=where
#    2488 )
#
# File J:\Anconda\Lib\site-packages\numpy\_core\fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %% [markdown]
# - np.nan represent float type
# - None represent Object type
# - if data operations related to Maths then nan format is better

# %% [markdown]
# **Fill the value based on column**

# %%
# df.fillna()
df['Names'].fillna('Manish')
# Out:
# 0     Ramesh
# 1     Suresh
# 2    Sathish
# 3     Manish
# Name: Names, dtype: object

# %% [markdown]
# **Fill with Method**

# %% [markdown]
# - Whever we are using methods no need to provide values

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# -pad
#
# -bfill
#
# -ffill
#
# -backfill

# %%
import warnings
warnings.filterwarnings('ignore')
df.fillna(method='pad',axis=1)
# fills the above values
# Out:
#      Names   Age    City
# 0   Ramesh  30.0    Pune
# 1   Suresh  22.0  Mumbai
# 2  Sathish  25.0    25.0
# 3     None  27.0   Delhi

# %%
df.fillna(method='bfill')
# Out:
#      Names   Age    City
# 0   Ramesh  30.0    Pune
# 1   Suresh  22.0  Mumbai
# 2  Sathish  25.0   Delhi
# 3     None  27.0   Delhi

# %%
df.fillna(method='ffill')
# Out:
#      Names   Age    City
# 0   Ramesh  30.0    Pune
# 1   Suresh  22.0  Mumbai
# 2  Sathish  25.0  Mumbai
# 3  Sathish  27.0   Delhi

# %%
df.fillna(method='backfill')
# Out:
#      Names   Age    City
# 0   Ramesh  30.0    Pune
# 1   Suresh  22.0  Mumbai
# 2  Sathish  25.0   Delhi
# 3     None  27.0   Delhi

# %% [markdown]
# **Mean--Median--Mode**

# %% [markdown]
# - instead of filling with random values
#
# - we can use mean median and mode also
#
# - For Numerical columns use mean and Median
#
#     - if Data outliers are there use Median
# - For categorical columns use Mode

# %%
# First calculate median 
# Then fill with median
age_median=df['Age'].median()
df['Age'].fillna(age_median)
# Out:
# 0    30.0
# 1    22.0
# 2    25.0
# 3    27.0
# Name: Age, dtype: float64

# %%
age_median
# Out:
# 26.0

# %%
mode=df['City'].mode()
mode
# Out:
# 0     Delhi
# 1    Mumbai
# 2      Pune
# Name: City, dtype: object

# %% [markdown]
# **KNN Immpter**
#
#     - K-Nearest Neighbours
#     - Where k= hyper parameters which means the user can change
#     - Idea: instead of taking all the samples
#         - First fix the neighbours number i.e. k
#         - Then find the neighnours using distance metric
#         - Then take the average of those samples to fill the missing value

# %%
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import KNNImputer

# %%
import numpy as np
import pandas as pd
from sklearn.impute import KNNImputer
X = [[1,2,np.nan],[3,np.nan,3],[np.nan,60,5],[8,8,7]]
pd.DataFrame(X)
# Out:
#      0     1    2
# 0  1.0   2.0  NaN
# 1  3.0   NaN  3.0
# 2  NaN  60.0  5.0
# 3  8.0   8.0  7.0

# %%
# import method 
# save method 
# fit tranform

# %%
from sklearn.impute import KNNImputer
X=[[1,2,np.nan],[3,np.nan,3],[np.nan,60,5],[8,8,7]]
imputer = KNNImputer(n_neighbors=2,
                    weights='uniform')
imputer.fit_transform(X)

# 8+3/2=5.5
# 60+2/2=31
# 7+3/2=5   2 is the neighbour
# Out:
# array([[ 1. ,  2. ,  5. ],
#        [ 3. , 31. ,  3. ],
#        [ 5.5, 60. ,  5. ],
#        [ 8. ,  8. ,  7. ]])

# %%
================= EDA Steps =======================
# interview question : Tell me about the EDA steps 
1. Read the data 
2. separate categorical columns and numerical Columns
3. Data quick checks shape, columns, dtypes, 
4. Null 
5. Do some data preprocess if any column is corrupted 
    ex: Numerical values in categorical clumns 
    ex: Categorical values in numerical columns 
6. Drop the Id type columns which means a Data has unique labels 
    Drop the Single value columns
7. Categorical column analysis 
        a) Frequency table 
        b) Bar charts
        c) Pie charts 
8. Numerical Column Anlysis 
        a) Histrogram
        b) Distribustion 
        c) Box plot 
9. Outlier analysis
    Impute the outliers with Median 
10. FInd the correlation Between numerical columns 
    Heat map
11. Convert cat to Numerical 
    A) LabelEncoder 
    B) One Hot Encoder 
12. Scale the data 
    A) Z standardization
    B) Normaization

by performing 12 steps, we achieve 3 things 
(i) Cleaned data
(ii) Data in the form of complete Numerical 
(iii) we have some understanding the data 

13. we will try to select the important feature fro ML model 
    A) PCA : principle component anlaysis (will be covered in ML)

Finally we achieve 3 data sets 

1. Till step-11:
    with out scale but data in Numerical format 
2. Till step-12:
    with scaling data in Numerical format 
3. Till step-13:
    PCA data
