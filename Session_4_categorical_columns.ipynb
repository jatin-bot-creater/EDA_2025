# %%
# import packages 
# read the data 
# divide into cat num columns 

import numpy as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

path='Visadataset.csv'
visa_df=pd.read_csv(path)
visa_df

cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **prevailing_wage**

# %% [markdown]
# - len
#
# - max
#
# - min
#
# - mean
#
# - median
#
# - 25 percentile
#
# - 50 percentile
#
# - 75  "

# %%
wage_data=visa_df['prevailing_wage']

# %%
wage_data=visa_df['prevailing_wage']
min(wage_data)
# Out:
# (2.1367,)

# %%
max(wage_data),wage_data.max(),np.max(wage_data)
# Out:
# (319210.27, 319210.27, 319210.27)

# %%
import numpy as np

# %%
wage_data.mean(),np
# Out:
# (np.float64(74455.81459209183),
#  <module 'numpy' from 'J:\\Anconda\\Lib\\site-packages\\numpy\\__init__.py'>)

# %%
np.max(wage_data)
# Out:
# 319210.27

# %%
wage_data.median()
# Out:
# 70308.20999999999

# %% [markdown]
# **Quantile-percentile**

# %%
p_25=np.percentile(wage_data,25)
p_25
# Out:
# np.float64(34015.479999999996)

# %%
p_50=np.percentile(wage_data,50)
p_50
# Out:
# np.float64(70308.20999999999)

# %%
p_75=np.percentile(wage_data,75)
p_75
# Out:
# np.float64(107735.51250000001)

# %%
q_25=np.quantile(wage_data,0.25)
q_50=np.quantile(wage_data,0.50)
q_75=np.quantile(wage_data,0.75)
q_75
# Out:
# np.float64(107735.51250000001)

# %%
# creating the table from the above data 
wage_data=visa_df['prevailing_wage']
wage_count=len(wage_data)
wage_min=round(wage_data.min(),2)
wage_mean=round(wage_data.mean(),2)
wage_med=round(wage_data.median(),2)
wage_25p=round(np.percentile(wage_data,25))
wage_50p=round(np.percentile(wage_data,50))
wage_75p=round(np.percentile(wage_data,75))
wage_max=round(wage_data.max(),2)
l=[wage_count,wage_mean,wage_mean,wage_med,wage_25p,wage_50p,wage_75p,wage_max]
Id=['count','Min','Min','Median','25p','50p','75p','Max']

pd.DataFrame(l,columns=['prevailing_wage'],index=Id)
# Out:
#         prevailing_wage
# count          25480.00
# Min            74455.81
# Min            74455.81
# Median         70308.21
# 25p            34015.00
# 50p            70308.00
# 75p           107736.00
# Max           319210.27

# %%
#wage_key=visa_df['prevailing_wage'].value_counts().keys()
#wage_values=visa_df['prevailing_wage'].value_counts().values
#wage_data=pd.DataFrame(zip(wage_key,wage_values),
 #                        columns=['continent','no of continent'],index=Id)

# %%
L=[]
for i in num:
    data=visa_df[i]
    count=len(data)
    Min=round(data.min(),2)
    mean=round(data.mean(),2)
    med=round(data.median(),2)
    p_25=round(np.percentile(data,25))
    p_50=round(np.percentile(data,50))
    p_75=round(np.percentile(data,75))
    Max=round(data.max(),2)
    
    l=[count,Min,mean,med,p_25,p_50,p_75,Max]

    L.append(l)
    
    Id=['count','Min','Mean','Median','25p','50p','75p','Max']
    
pd.DataFrame(L,columns=Id,index=num).T
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# count          25480.00     25480.00         25480.00
# Min              -26.00      1800.00             2.14
# Mean            5667.04      1979.41         74455.81
# Median          2109.00      1997.00         70308.21
# 25p             1022.00      1976.00         34015.00
# 50p             2109.00      1997.00         70308.00
# 75p             3504.00      2005.00        107736.00
# Max           602069.00      2016.00        319210.27

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# **Percentile concept**

# %% [markdown]
# - 25p: 25percentage of data below 25p value
#
# - wage_25p: 34015.48
#
#     - there 25*(25480)/100=6370 applicants have salary less than 34015
#
# - wage_50p: 70308.21
#
#     - there 50*(25480)/100= 12748 applicants have salary less than 70308
#
# - wage_75p: 107735.51
#
#     - there 75*(25480)/100= 19110 applicants have salary less than 107735

# %%
con=visa_df['prevailing_wage']<wage_25p
len(visa_df[con]),len(visa_df)*25/100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 con=visa_df['prevailing_wage']<wage_25p
#       2 len(visa_df[con]),len(visa_df)*25/100
#
# NameError: name 'wage_25p' is not defined

# %%
con=visa_df['prevailing_wage']<wage_50p
len(visa_df[con]),len(visa_df)*50/100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 con=visa_df['prevailing_wage']<wage_50p
#       2 len(visa_df[con]),len(visa_df)*50/100
#
# NameError: name 'wage_50p' is not defined

# %%
con=visa_df['prevailing_wage']<wage_75p
len(visa_df[con]),len(visa_df)*75/100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 con=visa_df['prevailing_wage']<wage_75p
#       2 len(visa_df[con]),len(visa_df)*75/100
#
# NameError: name 'wage_75p' is not defined

# %% [markdown]
# **Emperial rule**
#
# u-1*sigma to u+1*sigma 68%
#
# step-1: wage data mean(u)
#
# step-2: wage data std(sigma)
#
# step-3: LB=u-1*sigma
#
# step-4: UB=u+1*sigma
#
# step-5: con1=visa_df['prevailing_wage']>LB
# step-6: con1=visa_df['prevailing_wage']<UB
# step-7: con=con1 & con2
# step-8: len(visa_df[con])

# %%
u=round(wage_data.mean(),2)
u
# Out:
# np.float64(74455.81)

# %%
74455-1*2
# Out:
# 74453

# %%
LB=u-1*sigma
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 LB=u-1*sigma
#
# NameError: name 'sigma' is not defined

# %%
wage_data=visa_df['prevailing_wage']
U=wage_data.mean()
sigma=wage_data.std()
LB=U-1*sigma
UB=U+1*sigma
con1=visa_df['prevailing_wage']>LB
con2=visa_df['prevailing_wage']<UB
con=con1 & con2
len(visa_df[con])==68*25480/100
# Out:
# False

# %% [markdown]
# **Conclusion**=Emperial rule failed wage data doe snot following Normal distribution

# %% [markdown]
# ## Histrogram

# %%
plt.hist(wage_data,bins=40)
plt.show()

# %%
plt.hist(wage_data,bins=40)
# Out:
# (array([2992.,  871., 1005., 1170., 1242., 1434., 1385., 1443., 1444.,
#         1445., 1457., 1335., 1268., 1217., 1088.,  978.,  807.,  645.,
#          509.,  373.,  264.,  144.,  105.,  111.,  107.,   99.,   88.,
#           79.,   65.,   64.,   58.,   53.,   33.,   33.,   29.,   19.,
#            7.,    3.,    6.,    5.]),
#  array([2.13670000e+00, 7.98234003e+03, 1.59625434e+04, 2.39427467e+04,
#         3.19229500e+04, 3.99031534e+04, 4.78833567e+04, 5.58635600e+04,
#         6.38437634e+04, 7.18239667e+04, 7.98041700e+04, 8.77843734e+04,
#         9.57645767e+04, 1.03744780e+05, 1.11724983e+05, 1.19705187e+05,
#         1.27685390e+05, 1.35665593e+05, 1.43645797e+05, 1.51626000e+05,
#         1.59606203e+05, 1.67586407e+05, 1.75566610e+05, 1.83546813e+05,
#         1.91527017e+05, 1.99507220e+05, 2.07487423e+05, 2.15467627e+05,
#         2.23447830e+05, 2.31428033e+05, 2.39408237e+05, 2.47388440e+05,
#         2.55368643e+05, 2.63348847e+05, 2.71329050e+05, 2.79309253e+05,
#         2.87289457e+05, 2.95269660e+05, 3.03249863e+05, 3.11230067e+05,
#         3.19210270e+05]),
#  <BarContainer object of 40 artists>)

# %%
# bins means intervals
inter_count,inter_vals,n=plt.hist(wage_data,bins=10)

# %%
inter_count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 inter_count
#
# NameError: name 'inter_count' is not defined

# %%
inter_vals
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 inter_vals
#
# NameError: name 'inter_vals' is not defined

# %% [markdown]
# inter_vals-2.13670000e+00, 3.19229500e+04
# inter_count-6038
#
# bwt these two values 6038 values are their

# %%
wage_data=visa_df['prevailing_wage']
LB=2.13670000e+00
UB=3.19229500e+04
con1=wage_data>=LB
con2=wage_data<UB
con=con1 & con2
len(visa_df[con])
# Out:
# 6038

# %% [markdown]
# ## outlier Analysis

# %% [markdown]
# - we under stood emperial rule failed
#
# - then we plotted histogram its slightly deviated
#
# - So it indicates the data has outliers
#
# - Outliers can be show by box plots

# %% [markdown]
# ## Boxplot

# %%
import numpy as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

path='Visadataset.csv'
visa_df=pd.read_csv(path)
visa_df

cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values
df=pd.DataFrame(zip(keys,values),columns=['continent name','Total no of applicant'])
df.to_csv('continent_df.csv',index=False)

# %%
wage_data=visa_df('prevailing_wage')
plt.boxplot(wage_data,vert=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 wage_data=visa_df('prevailing_wage')
#       2 plt.boxplot(wage_data,vert=False)
#
# TypeError: 'DataFrame' object is not callable

# %%
plt.figure(figsize=(8,4))
plt.subplot(1,2,1).histrogram(wage_data)
plt.subplot(1,2,2).boxplot(wage_data,vert=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 plt.figure(figsize=(8,4))
# ----> 2 plt.subplot(1,2,1).histrogram(wage_data)
#       3 plt.subplot(1,2,2).boxplot(wage_data,vert=False)
#
# AttributeError: 'Axes' object has no attribute 'histrogram'

# %% [markdown]
# ## outliers data

# %%
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q1-1.5*IQR
con1=wage_data>UB
con2=wage_data<LB
con=con1 | con2
outliers_df=visa_df[con]
len(outliers_df)
# Out:
# 427

# %%
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q1-1.5*IQR
con1=wage_data<UB
con2=wage_data>LB
con=con1 & con2
outliers_df=visa_df[con]
len(outliers_df)
# Out:
# 25053

# %% [markdown]
# ## Fill the outliers

# %%
# con1= wage_data >UB
# con2= wage_data <LB
# con= con1 | con2
# outliers

# %%
plt.figure(figsize=(8,4))
plt.subplot(2,2,1).hist(visa_df['prevailing_wage1'])
plt.subplot(2,3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File J:\Anconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'prevailing_wage1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 2
#       1 plt.figure(figsize=(8,4))
# ----> 2 plt.subplot(2,2,1).hist(visa_df['prevailing_wage1'])
#       3 plt.subplot(2,3)
#
# File J:\Anconda\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File J:\Anconda\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'prevailing_wage1'
