# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

path='Visadataset.csv'
visa_df=pd.read_csv(path)

cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %% [markdown]
# - We have two types of scaling
#     - Z score (Standardization)
#     - Min max scalar (Narmalization)

# %%
Image(url="https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.simplypsychology.org%2Fz-score.html&psig=AOvVaw1rRAfYLUBo4g_Z4yQrh3TQ&ust=1758378160142000&source=images&cd=vfe&opi=89978449&ved=0CBUQjRxqFwoTCJC_2Z-D5Y8DFQAAAAAdAAAAABAE")
# Out:
# <img src="https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.simplypsychology.org%2Fz-score.html&psig=AOvVaw1rRAfYLUBo4g_Z4yQrh3TQ&ust=1758378160142000&source=images&cd=vfe&opi=89978449&ved=0CBUQjRxqFwoTCJC_2Z-D5Y8DFQAAAAAdAAAAABAE"/>

# %%
# step-1 : read pwage column x
# step-2 : calculate mean pwage
# step-3 : calculate std of wage
# step-4 : pwage-mean
# step-5 : visa_df[p_z] step 4/step 3

# %%
wageData = visa_df['prevailing_wage']
mean_wageData = wageData.mean()
std_wageData =  wageData.std()
visa_df['prevailing_wage_z'] = (wageData - mean_wageData)/std_wageData

# %%
visa_df[['prevailing_wage','prevailing_wage_z']]
# Out:
#        prevailing_wage  prevailing_wage_z
# 0             592.2029          -1.398510
# 1           83425.6500           0.169832
# 2          122996.8600           0.919060
# 3           83434.0300           0.169991
# 4          149907.3900           1.428576
# ...                ...                ...
# 25475       77092.5700           0.049923
# 25476      279174.7900           3.876083
# 25477      146298.8500           1.360253
# 25478       86154.7700           0.221504
# 25479       70876.9100          -0.067762
#
# [25480 rows x 2 columns]

# %%
plt.subplot(2,2,1).hist(wageData)
plt.subplot(2,2,2).boxplot(wageData,vert=False)
plt.subplot(2,2,3).hist(d['prevailing_wage_z'])
plt.subplot(2,2,4).boxplot(d['prevailing_wage_z'],vert=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 3
#       1 plt.subplot(2,2,1).hist(wageData)
#       2 plt.subplot(2,2,2).boxplot(wageData,vert=False)
# ----> 3 plt.subplot(2,2,3).hist(d['prevailing_wage_z'])
#       4 plt.subplot(2,2,4).boxplot(d['prevailing_wage_z'],vert=False)
#
# KeyError: 'prevailing_wage_z'

# %% [markdown]
# **sklearn**
#
#     - **preprocessing**
#
#           -**StandardScalar**
#
# - import the method
#
# - save the method
#
# - apply fit trsnsfor

# %%
from sklearn.preprocessing import StandardScalar
ss=StandardScalar()
visa_df['prevailing_wage_ss']=ss.fit_transform(visa_df[['prevailing_wage']])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 from sklearn.preprocessing import StandardScalar
#       2 ss=StandardScalar()
#       3 visa_df['prevailing_wage_ss']=ss.fit_transform(visa_df[['prevailing_wage']])
#
# ImportError: cannot import name 'StandardScalar' from 'sklearn.preprocessing' (J:\Anconda\Lib\site-packages\sklearn\preprocessing\__init__.py)

# %%
visa_df['prevailing_wage','prevailing_wage_z','prevailing_wage_ss']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File J:\Anconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('prevailing_wage', 'prevailing_wage_z', 'prevailing_wage_ss')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ...

# %% [markdown]
# **Normalization**

# %%
Do based on formula 
Methoed name : MinMaxScalar
Compare both answers

# %%
#
