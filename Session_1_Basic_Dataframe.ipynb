# %% [markdown]
# ================== Data Analysis ====================
#
# 1. Pandas              : Data frame analysis
# 2. Numpy               : Numerical analysis
# 3. matplotlib          : Graphs and plots
# 4. seaborn             : plots
# 5. Bokhe               : plots
# 6. plotly              : plots
#
#
# ================== Machine Learning =================
#
# 7. stats                 : for statistical models
# 8. scikit-learn(sklearn) : ML models
#
# ================== Deep Learning ===================
#
# 9.opencv                : Computer vision
# 10.pillow               : Image operations
# 11.Tensor Flow          : Neural Network creations (developed by google)
# 12.keras                : NN
# 13. pytorch             : alternative package of tensorflow (fackbook meta)
#
# ================= NLP ================================
#
# 14. NLTK                 : Natural language toolkit
# 15. Spacy                : Alternative to NLTK
# 16. wordcloud            : most frequent occured words
#
# ===================Scrapping ==========================
#
# 17. SqLite               : Data base creation
# 18. Beautiful soup
# 19. Seleium
#
# ====================API creation ===========================
#
# 20.Flask
# 21.FastAPI
# 22.Gradio
# 23.Django
#
# ===================== UI app creations =======================
#
# 24. Streamlit
#
# =====================Transfer learning models (DL)=======================
#
# 25.Mobilenet
# 26.Resnet
# 27.VGGnet
# 28.Inception
# 29.Yolo                : Ultralytics
#
# ===================== Transfer learning models(NLP)=======================
#
# 30. Word2vec
# 31. GloVe
#
# =======================Huging Face Transformation ========================
#
# 32. Allen NLP packages
#
# ======================== GenAI ====================================
#
# 34. LangChain
# 35. Google GeminiAi realted Packages
# 36. OpenAI GPT realted Packages
# 37. Amazon BedRock realted packages
# 38. Meta Lama realted packages
#
# ======================== Image and Video Generations ======================
#
# 39. GAN models related packages
# 40. SORA related packages
#
# ============================ Model development (Mlops) ===================
#
# 41. mlflow using databricks
# 42. kubeflow (GCP account)
#
# ============================= Cloud applictions =====================
#
# 43. Azure ML realted packages
# 44. GCP VertexAI
# 45. AWS Sagemaker realted packages
#
# ================================= Small ===============================
#
# 46. time
# 47. logging
# 48. math
# 49. random
# 50. env

# %% [markdown]
# **Step :1 Import packages**

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Step :2 Create a data frame using list**
#
# - data
#
# - index
#
# - columns

# %%
#names=['Ramesh','Suresh','Satish']
#pd.DataFrame(names,
#             columns=['names'])
names=['Ramesh','Suresh','Satish']
pd.DataFrame(names,
            columns=['names'])
# Out:
#     names
# 0  Ramesh
# 1  Suresh
# 2  Satish

# %% [markdown]
# **Step 3: Change the index**

# %%
names=['Ramesh','Suresh','Satish']
pd.DataFrame(names,
             index=['i','ii','iii'],
             columns=['names'])


# fruits=['Jackfruit','Mango','Jamun']
# pd.DataFrame(fruits,
#            index=['a','b','c'],
#            columns=['fruits'])
# Out:
#       names
# i    Ramesh
# ii   Suresh
# iii  Satish

# %%
names=['Ramesh','Suresh','Satish']
idx=['A','B','C']
col=['names']
pd.DataFrame(names,idx,col)
# Out:
#     names
# A  Ramesh
# B  Suresh
# C  Satish

# %% [markdown]
# **Step 4: Add multiplty columns**

# %%
names=['Ramesh','Suresh','Satish']
age=[10,20,30]
pd.DataFrame(zip(names,age),columns=['names','age'])
# Out:
#     names  age
# 0  Ramesh   10
# 1  Suresh   20
# 2  Satish   30

# %%
np.__version__
# Out:
# '2.1.3'

# %% [markdown]
# **Step-5: Create emplty dataframe and update the columns**

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df=pd.DataFrame()
df['Names']=['Ramesh','Suresh','Mahesh']
df['Age']=['10','20','30']
df
# Out:
#     Names Age
# 0  Ramesh  10
# 1  Suresh  20
# 2  Mahesh  30

# %% [markdown]
# **Step-6 : Add a new column with existing dataframe**

# %%
names=['Ramesh','Suresh','Satish']
age=[10,20,30]
df=pd.DataFrame(zip(names,age),
                columns=['names','age'])
df['Gender']=['M','M','M']
df
# Out:
#     names  age Gender
# 0  Ramesh   10      M
# 1  Suresh   20      M
# 2  Satish   30      M

# %% [markdown]
# **Step-7: Overwrite the column**

# %%
df['Age']=[30,40,50]
df
# if we change the small 'a' to 'A' then it will create the new column
# Out:
#     names  age Gender  Age
# 0  Ramesh   10      M   30
# 1  Suresh   20      M   40
# 2  Satish   30      M   50

# %% [markdown]
# **Step-8: Drop the column**
#
# - lables
#
# - axis
#
# - index
#
# - columns
#
# - inplace

# %%
df.drop('age')   # error
# here python asssume age is a label 
# python ask qn : is it index label or column label 
# axis =1 means for columns
# axis =0 means for rows
# by defaults axis=0

# %%
df.drop('age',axis=0)   # error
# even 0 also it will take error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.drop('age',axis=0)
#
# File J:\Anconda\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File J:\Anconda\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File J:\Anconda\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File J:\Anconda\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['age'] not found in axis"

# %%
df.drop('Age',axis=1)
# Out:
#     names  age Gender
# 0  Ramesh   10      M
# 1  Suresh   20      M
# 2  Satish   30      M

# %%
df
# we are able to see old coulmn 
# because we did not apply inplace =True
# Out:
#     names  age Gender  Age
# 0  Ramesh   10      M   30
# 1  Suresh   20      M   40
# 2  Satish   30      M   50

# %%
df.drop(columns=['Age'],inplace=True)

# %%
df
# Out:
#     names  age Gender
# 0  Ramesh   10      M
# 1  Suresh   20      M
# 2  Satish   30      M

# %%
df.drop(index=2,
       axis=0)
# drop the index 2
# Out:
#     names  age Gender
# 0  Ramesh   30      M
# 1  Suresh   40      M

# %% [markdown]
# **Step-9 : Remane the col**

# %%
    mapper: 'Renamer | None' = None,
    *,
    index: 'Renamer | None' = None,
    columns: 'Renamer | None' = None,
    axis: 'Axis | None' = None,
    copy: 'bool | None' = None,
    inplace: 'bool' = False,
    level: 'Level | None' = None,
    errors: 'IgnoreRaise' = 'ignore',
) -> 'DataFrame | None'

# %%
name=['jatin','praneeth','amit']
age=['10','20','30']
city=['MP','JK','DEl']
pd.DataFrame(zip(name,age,city),
            columns=['Name','Age','City'])
#df.rename()
# Out:
#        Name Age City
# 0     jatin  10   MP
# 1  praneeth  20   JK
# 2      amit  30  DEl

# %%
# direct call the list
dict_name={'age':'AGE'}
df.rename(columns=dict_name)
# Out:
#     names  AGE Gender
# 0  Ramesh   10      M
# 1  Suresh   20      M
# 2  Satish   30      M

# %%
# calling the axis 
dict_name={'age':'AGE'}
df.rename(dict_name,axis=1)
# Out:
#     names  AGE Gender
# 0  Ramesh   10      M
# 1  Suresh   20      M
# 2  Satish   30      M

# %%
# calling the inplace 
dict_name={'age':'AGE'}
df.rename(columns=dict_name,inplace=True)
df
# Out:
#     names  AGE Gender
# 0  Ramesh   10      M
# 1  Suresh   20      M
# 2  Satish   30      M

# %%
# can you change 2 to 'B'
# sir whats the diff btw labels and index sir ?
# index 0,1,2
# columns Names, Age, city

# %%
dict1={2:'b'}
df.rename(dict1)
# Out:
#     names  AGE Gender
# 0  Ramesh   10      M
# 1  Suresh   20      M
# b  Satish   30      M

# %%
df1=pd.DataFrame()
df1['value']=[i for i in range(1,10)]
df1['square_value']=[i*i for i in range(1,10)]
df1['cube_value']=[i*i*i for i in range(1,10)]
df1
# Out:
#    value  square_value  cube_value
# 0      1             1           1
# 1      2             4           8
# 2      3             9          27
# 3      4            16          64
# 4      5            25         125
# 5      6            36         216
# 6      7            49         343
# 7      8            64         512
# 8      9            81         729

# %%
dir(df1)
# Out:
#   Cell In[31], line 1
#     dir(df1))
#             ^
# SyntaxError: unmatched ')'

# %% [markdown]
# - len
#
# - columns
#
# - shape
#
# - dtypes
#
# - head
#
# - tail

# %%
len(df1)
# Out:
# 9

# %%
df1.columns
# Out:
# Index(['value', 'square_value', 'cube_value'], dtype='object')

# %%
df1.shape
# Out:
# (9, 3)

# %%
df1.dtypes
# Out:
# value           int64
# square_value    int64
# cube_value      int64
# dtype: object

# %%
df.dtypes
# Out:
# names     object
# AGE        int64
# Gender    object
# dtype: object

# %%
df1.head()
# Out:
#    value  square_value  cube_value
# 0      1             1           1
# 1      2             4           8
# 2      3             9          27
# 3      4            16          64
# 4      5            25         125

# %%
df1.tail()
# Out:
#    value  square_value  cube_value
# 4      5            25         125
# 5      6            36         216
# 6      7            49         343
# 7      8            64         512
# 8      9            81         729

# %%
df1.isnull()
# Out:
#    value  square_value  cube_value
# 0  False         False       False
# 1  False         False       False
# 2  False         False       False
# 3  False         False       False
# 4  False         False       False
# 5  False         False       False
# 6  False         False       False
# 7  False         False       False
# 8  False         False       False

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   value         9 non-null      int64
#  1   square_value  9 non-null      int64
#  2   cube_value    9 non-null      int64
# dtypes: int64(3)
# memory usage: 348.0 bytes

# %% [markdown]
# **Step-10 : How to change a specific value of a column**

# %%
-df1.drop
    - either it will drop column or index

- df1.rename
    - either it will rename column or index

- df1.replace

# %%
df1.replace(to_replace=64,value=464)
# Out:
#    value  square_value  cube_value
# 0      1             1           1
# 1      2             4           8
# 2      3             9          27
# 3      4            16         464
# 4      5            25         125
# 5      6            36         216
# 6      7            49         343
# 7      8           464         512
# 8      9            81         729

# %% [markdown]
# **Step-11: Selection of a column**

# %%
df1['cube_value']
# series
# series looks like dataframe
# Out:
# 0      1
# 1      8
# 2     27
# 3     64
# 4    125
# 5    216
# 6    343
# 7    512
# 8    729
# Name: cube_value, dtype: int64

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df1['cube_value'])
# 2D data
# Out:
# pandas.core.series.Series

# %%
df1['cube_value'].shape
# 1D data
# Out:
# (9,)

# %%
df1[['cube_value']]
# Out:
#    cube_value
# 0           1
# 1           8
# 2          27
# 3          64
# 4         125
# 5         216
# 6         343
# 7         512
# 8         729

# %%
type(df1[['cube_value']])
df1[['cube_value']].shape
# Out:
# (9, 1)

# %%
# square_value
# cube_value
# multiple always keep those in list
df1[['cube_value','square_value']]
# Out:
#    cube_value  square_value
# 0           1             1
# 1           8             4
# 2          27             9
# 3          64            16
# 4         125            25
# 5         216            36
# 6         343            49
# 7         512            64
# 8         729            81

# %% [markdown]
# **Step-12:How to append a row**

# %% [markdown]
# - loc
#
# - iloc

# %%
df1.loc[rows,columns]
df1.iloc[rows,columns]
#we can select particular rows and coulmns using 

df1.iloc[3:7,1:3]
df1.loc[3:7,['square_value','cube_value']]
cols=['square_value','cube_value']
df1.loc[3:7,cols]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df1.loc[rows,columns]
#       2 df1.iloc[rows,columns]
#       3 #we can select particular rows and coulmns using
#
# NameError: name 'df1' is not defined

# %%
df1.iloc[[2,3,4]]
df1.iloc[[2]]
df1.iloc[2]
df1.iloc[[2,3,4],[0,2]]
df1.iloc[2,0]
df1.iloc[:,0]
df1.iloc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df1.iloc[[2,3,4]]
#       2 df1.iloc[[2]]
#       3 df1.iloc[2]
#
# NameError: name 'df1' is not defined
